# %% [markdown]
# <a href="https://colab.research.google.com/github/gaolichen/machine-learning-examples/blob/main/dog_vs_cat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
from train import Settings, run, plot_hist
train_file_url = 'https://storage.googleapis.com/kagglesdsdata/competitions/5441/38425/train.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1635749634&Signature=W6MdzagFAfB0ww9A8U5fR5sJe8ScjTCxdvKtovOREnJaPy%2FwIvLDNmEt4y4CRqpjxq%2FqPXppQT%2B1koVqj1qe36oklfffu5yYke4gECQIloR%2FuRUIBUvweEIKGOJIah0faK0INjgUVWSXv9yaUn4Ar5%2BpyxqLLU4pGs14XAyHyoByNotloWf1MP%2FED1hNGY45e80rDVr%2BAYdaVQc1u0RLAw%2B4Fsa%2BD2ujbWmomY6Pmp1gudSZIZ6K0yxnCiMxEDa3R1ovY5T3c%2BgJixoy9Ls1G4JGXS2dsAxNAtQ8gihC1ToEiK%2F7ZIT%2F1LYnmw8rxZY8E%2BwU4XJ0wljH83PfVUS9iA%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain.zip'
test_file_url = 'https://storage.googleapis.com/kagglesdsdata/competitions/5441/38425/test.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1635749907&Signature=W2%2BZWFnd8MyabMUn8xoN8YkPMq%2BmILaJSw5leNfHt%2BtxqXdmLC2%2BDFpA4kAxQdMvGHve4W9U2tMHItpawlnoz6s74GFgW9rZ58lOjhl%2BNxJ09o045oaF4vASld9a0mAmPJMW2K3Y6GfUORTighuc4pNxpeKvUvVQTwHjzsn11Zr8xmU1uS0D0%2Fx14bEOd%2Bdiopg0AphUk4ANLG7qfOj5OOIFCL6UtQh4e7gwjB45YBZjsMDlUo9Cspjcf2yEYcdU8Z8R4viSJn82L1Ch2w0hw6piL08Io5N72BgEjvEaMo42n3CRk4B9fKdXSvSMHUFUDp1woAVOjO6xVBSHDv53XQ%3D%3D&response-content-disposition=attachment%3B+filename%3Dtest.zip'
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# # Custom CNN Model

# %%
settings = Settings(data_dir = '.',
    model_name = 'custom cnn',
    train_download_path = train_file_url, 
    test_download_path = test_file_url,
    epochs = 20)
    
hist = run(settings)
plot_hist(hist, settings.model_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# finished downloading train.zip
# finished downloading test.zip
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2D_block1_1 (Conv2D)     (None, 150, 150, 16)      448
# _________________________________________________________________
# conv2D_block1_2 (Conv2D)     (None, 148, 148, 16)      2320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 148, 148, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# ...

# %% [markdown]
# # Fine-tune VGG16 Model

# %%
settings = Settings(data_dir = '.',
    model_name = 'VGG16',
    train_download_path = train_file_url, 
    test_download_path = test_file_url,
    first_turning_layer = 2,
    epochs = 5)
    
hist = run(settings, preview_only = False)
plot_hist(hist, settings.model_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# finished downloading train.zip
# finished downloading test.zip
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_17 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# ...

# %% [markdown]
# # Fine-tune VGG19 Model

# %%
settings = Settings(data_dir = '.',
    model_name = 'VGG19',
    train_download_path = train_file_url, 
    test_download_path = test_file_url,
    first_turning_layer = 2,
    epochs = 5)
    
hist = run(settings, preview_only = False)
plot_hist(hist, settings.model_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# finished downloading train.zip
# finished downloading test.zip
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_18 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# ...

# %% [markdown]
# # Fine-tune ResNet50 Model

# %%
settings = Settings(data_dir = '.',
    model_name = 'ResNet50',
    train_download_path = train_file_url, 
    test_download_path = test_file_url,
    first_turning_layer = 4,
    epochs = 5)
    
hist = run(settings, preview_only = False)
plot_hist(hist, settings.model_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# finished downloading train.zip
# finished downloading test.zip
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_19 (InputLayer)           [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 156, 156, 3)  0           input_19[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 75, 75, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# # Fine-tune Xception Model

# %%
settings = Settings(data_dir = '.',
    model_name = 'Xception',
    train_download_path = train_file_url, 
    test_download_path = test_file_url,
    first_turning_layer = 3,
    epochs = 5)
    
hist = run(settings, preview_only = False)
plot_hist(hist, settings.model_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# finished downloading train.zip
# finished downloading test.zip
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_20 (InputLayer)           [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 74, 74, 32)   864         input_20[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 74, 74, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# # Fine-tune ReseNet50V2 model

# %%
settings = Settings(data_dir = '.',
    model_name = 'ResNet50V2',
    train_download_path = train_file_url, 
    test_download_path = test_file_url,
    first_turning_layer = 4,
    epochs = 5)

hist = run(settings, preview_only = False)
plot_hist(hist, settings.model_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# finished downloading train.zip
# finished downloading test.zip
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_21 (InputLayer)           [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 156, 156, 3)  0           input_21[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 75, 75, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# # Fine-Tune InceptionResNetV2 Model

# %%
settings = Settings(data_dir = '.',
    model_name = 'InceptionResNetV2',
    train_download_path = train_file_url, 
    test_download_path = test_file_url,
    first_turning_layer = 3,
    epochs = 5)

hist = run(settings, preview_only = False)
plot_hist(hist, settings.model_name)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# finished downloading train.zip
# finished downloading test.zip
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_22 (InputLayer)           [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv2d_418 (Conv2D)             (None, 74, 74, 32)   864         input_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_421 (BatchN (None, 74, 74, 32)   96          conv2d_418[0][0]
# ...
